# %% [markdown]
# <a href="https://colab.research.google.com/github/Thalapathi26/AI_ML/blob/main/FNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/personality_datasert.csv')

# %%
df
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0                  4.0         No                      4.0            6.0
# 1                  9.0        Yes                      0.0            0.0
# 2                  9.0        Yes                      1.0            2.0
# 3                  0.0         No                      6.0            7.0
# 4                  3.0         No                      9.0            4.0
# ...                ...        ...                      ...            ...
# 2895               3.0         No                      7.0            6.0
# 2896               3.0         No                      8.0            3.0
# 2897               4.0        Yes                      1.0            1.0
# 2898              11.0        Yes                      1.0            3.0
# 2899               3.0         No                      6.0            6.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
df.isnull().sum()
# Out:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# Friends_circle_size          0
# Post_frequency               0
# Personality                  0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
for i in df.columns:
  if df[i].dtype=='float64':
    df[i]=sc.fit_transform(df[[i]])

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0         -0.147014         No                 0.012759       1.350613
# 1          1.306226        Yes                -1.379944      -1.350613
# 2          1.306226        Yes                -1.031768      -0.450204
# 3         -1.309607         No                 0.709111       1.800817
# 4         -0.437663         No                 1.753638       0.450204
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No             1.590680        0.496104   Extrovert
# 1                       Yes            -1.481437       -0.195199   Introvert
# 2                       Yes            -0.299853       -0.540850   Introvert
# 3                        No             1.826996        1.533059   Extrovert
# 4                        No             0.409096        0.496104   Extrovert

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
  if df[i].dtype=='object':
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0         -0.147014           0                 0.012759       1.350613
# 1          1.306226           1                -1.379944      -1.350613
# 2          1.306226           1                -1.031768      -0.450204
# 3         -1.309607           0                 0.709111       1.800817
# 4         -0.437663           0                 1.753638       0.450204
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                          0             1.590680        0.496104            0
# 1                          1            -1.481437       -0.195199            1
# 2                          1            -0.299853       -0.540850            1
# 3                          0             1.826996        1.533059            0
# 4                          0             0.409096        0.496104            0

# %%
x=df.drop('Personality',axis=1)
y=df['Personality']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=52)

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential([
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
fnn=model.fit(x_train,y_train,epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9043 - loss: 0.3689
# Epoch 2/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2686
# Epoch 3/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.2616
# Epoch 4/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2526
# Epoch 5/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.2473
# Epoch 6/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2415
# Epoch 7/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.2359
# Epoch 8/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.2323
# Epoch 9/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2309
# Epoch 10/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2290
# Epoch 11/100
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2252
# Epoch 12/100
# ...

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# array([[9.96199250e-01],
#        [7.05891941e-03],
#        [1.55093353e-02],
#        [8.67121041e-01],
#        [7.84928441e-01],
#        [6.51620552e-02],
#        [1.09925484e-02],
#        [9.92533565e-01],
#        [9.14135831e-04],
#        [4.05361038e-03],
#        [9.77055967e-01],
#        [1.27905920e-01],
#        [1.28439367e-02],
#        [8.58961046e-01],
#        [2.30223988e-03],
#        [2.91400589e-02],
#        [1.84262414e-02],
#        [6.91343993e-02],
#        [9.51100409e-01],
#        [3.22003625e-02],
#        [9.19899106e-01],
#        [3.58974584e-03],
#        [9.89624023e-01],
#        [9.36071634e-01],
#        [6.41332287e-03],
#        [3.29609215e-02],
#        [9.72743571e-01],
#        [8.36387575e-01],
#        [9.78513181e-01],
#        [1.58223358e-03],
#        [9.55410302e-01],
#        [8.58454645e-01],
#        [3.35256666e-01],
#        [9.42173302e-01],
#        [9.81198549e-01],
# ...
